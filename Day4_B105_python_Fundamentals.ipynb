# %%
Students=['ashar','ahmar','fouzan','areeb','faaz']
print(Students)
# Out:
# ['ashar', 'ahmar', 'fouzan', 'areeb', 'faaz']

# %%
print(Students[2])
# Out:
# fouzan

# %%
Students.append('sharukh') #To add element in the list
print(Students)
# Out:
# ['ashar', 'ahmar', 'fouzan', 'areeb', 'faaz', 'sharukh']

# %%
Students.insert(3,'Sarah') #To add element at specific index position
print(Students)
# Out:
# ['ashar', 'ahmar', 'fouzan', 'Sarah', 'Sharukh', 'areeb', 'faaz', 'sharukh']

# %%
print(Students)
# Out:
# ['ashar', 'ahmar', 'fouzan', 'Sarah', 'Sharukh', 'areeb', 'faaz', 'sharukh']

# %%
del Students[2] #To delete element from the list
print(Students)
# Out:
# ['ashar', 'ahmar', 'Sarah', 'Sharukh', 'areeb', 'faaz', 'sharukh']
