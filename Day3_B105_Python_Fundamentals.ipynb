# %%
firstname='ashar'
lastname='rehman'
fullname=f"{firstname} {lastname}"
print(fullname)
# Out:
# ashar rehman

# %%
print(fullname.title())
# Out:
# Ashar Rehman

# %%
message=f"keep it up, {fullname.title()}"
print(message)
# Out:
# keep it up, Ashar Rehman

# %%
print("fav_programming:\nPython\nC\nC++\nJava\nSwift\nJavascript")
# Out:
# fav_programming:
# Python
# C
# C++
# Java
# Swift
# Javascript

# %%
print("fav_programming:\n\tPython\n\tC\n\tC++\n\tJava\n\tSwift\n\tJavascript")
# Out:
# fav_programming:
# 	Python
# 	C
# 	C++
# 	Java
# 	Swift
# 	Javascript

# %%
#Eliminating whitespaces:

# %%
name=' C++'
print(name)
# Out:
#  C++

# %%
name1='C++ '
print(name1)
# Out:
# C++

# %%
name.lstrip()
# Out:
# 'C++'

# %%
name1.rstrip()
# Out:
# 'C++'
