# %%
firstname='ashar'
print(firstname)
# Out:
# ashar

# %%
name1='Rehman'
print(name1)
# Out:
# Rehman

# %%
a=10
b=20

# %%
c=a+b
print(c)
# Out:
# 30

# %%
type(c) #if we want to find what type of variable c is
# Out:
# int

# %%
#req: if i want to change name into capital letter

# %%
print(name1.upper())
# Out:
# REHMAN

# %%
fullname="ashar rehman"

# %%
print(fullname.title())
# Out:
# Ashar Rehman

# %% [raw]
# print(
